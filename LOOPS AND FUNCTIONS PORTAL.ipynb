# %% [markdown]
# **LOOPS AND FUNCTIONS**

# %%
for i in range(5):
    print(f"Iteration {i}")

# %%
user_input = ""
while user_input.lower() != "exit":
    user_input = input("Type 'exit' to stop: ")

# %%
def calculate_tax(price, rate=0.07):
    return price * rate

total_tax = calculate_tax(100) # Reusable and clean
