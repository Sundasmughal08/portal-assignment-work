# %% [markdown]
# **data type**

# %%
name = "sundas"
age = 23
city = "gujranwala"
print(name)
print(age)
print(city)
# Out:
# sundas
# 23
# gujranwala

# %% [markdown]
# **data type**

# %%
print(type(name))
print(type(age))
print(type(city))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'str'>

# %% [markdown]
# **add sub multiply**

# %%
a , b = 15,5
print(f"addition: {a+b}")
print(f"subtraction: {a-b}")
print(f"multiplication: {a*b}")
print(f"divide: {a/b}")
# Out:
# addition: 20
# subtraction: 10
# multiplication: 75
# divide: 3.0

# %% [markdown]
# c**omparison**

# %%
a , b = 4,6
print(x<y)
print(x>y)
print(x==y)
# Out:
# True
# False
# False

# %% [markdown]
# **type casting and info**

# %%
num_int = 5
num_float = float(num_int)  # 5.0
back_to_int = int(num_float) # 5

student_name = "Jordan"
roll_number = 101
marks = 85

marks += 5   
marks -= 2  
marks *= 1.1 

print(f"Student: {student_name} | Roll: {roll_number} | Final Marks: {marks}")
# Out:
# Student: Jordan | Roll: 101 | Final Marks: 96.80000000000001

# %% [markdown]
# **and or not operation**

# %%
is_sunny = True
is_weekend = False

print(is_sunny and is_weekend) # False (Both must be True)
print(is_sunny or is_weekend)  # True (At least one is True)
print(not is_sunny)            # False (Flips the value)
# Out:
# False
# True
# False

# %% [markdown]
# **area calculate**

# %%
length = 10.5
width = 5.0
area = length * width

print(f"The area of the rectangle is: {area}")
# Out:
# The area of the rectangle is: 52.5
